# %%
import urllib.request
import pandas as pd

# %%
url = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=2018&$limit=10000"
checkout_file = "checkout.csv"
urllib.request.urlretrieve(url, checkout_file)
# Out:
# ('checkout.csv', <http.client.HTTPMessage at 0x7f528c52fbb0>)

# %%
checkouts_df = pd.read_csv(checkout_file)

# %%
checkouts_df
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0       Digital    OverDrive        EBOOK          2018              1
# 1       Digital       Hoopla   TELEVISION          2018              1
# 2      Physical      Horizon    SOUNDDISC          2018              1
# 3       Digital    OverDrive        EBOOK          2018              1
# 4       Digital    OverDrive        EBOOK          2018              1
# ...         ...          ...          ...           ...            ...
# 9995    Digital    OverDrive    AUDIOBOOK          2018              1
# 9996    Digital    OverDrive        EBOOK          2018              1
# 9997   Physical      Horizon         BOOK          2018              1
# 9998   Physical      Horizon         BOOK          2018              1
# 9999    Digital    OverDrive    AUDIOBOOK          2018              1
#
#       checkouts                                              title  \
# ...

# %%
checkouts_df["checkoutmonth"].unique()
# Out:
# array([ 1,  2,  3,  4,  5,  8,  9, 10, 11, 12])

# %%
checkouts_df["materialtype"].unique()
# Out:
# array(['EBOOK', 'TELEVISION', 'SOUNDDISC', 'BOOK', 'AUDIOBOOK', 'COMIC',
#        'MOVIE', 'SONG', 'MUSIC', 'MAGAZINE', 'VIDEODISC', 'SOUNDREC',
#        'SOUNDDISC, VIDEODISC', 'CR', 'LARGEPRINT', 'ER, SOUNDDISC',
#        'ATLAS', 'ER', 'MAP', 'VIDEOCASS, VIDEODISC', 'REGPRINT', 'VIDEO',
#        'SOUNDCASS', 'ER, VIDEODISC'], dtype=object)

# %%
checkouts_df[checkouts_df["materialtype"] == "EBOOK"].count()
# Out:
# usageclass         2088
# checkouttype       2088
# materialtype       2088
# checkoutyear       2088
# checkoutmonth      2088
# checkouts          2088
# title              2088
# creator            2088
# subjects           2086
# publisher          2088
# publicationyear    2088
# dtype: int64

# %%
checkouts_df["checkouts"].count()
# Out:
# 10000

# %%
checkouts_df["checkouts"].unique()
# Out:
# array([ 22,   1,   2,   4,  20,   3,   5,  18,   8,  12,   6,  13,  49,
#         52,   7,  11,  10,  34,  19,   9,  35,  16,  64,  21,  30,  17,
#         15,  79,  50,  61,  32,  95,  23,  14,  24,  71,  38,  29,  43,
#         44,  25,  39,  28,  26,  65, 105,  56,  42,  58,  84,  51, 106,
#         81,  27,  82,  62,  66,  46,  57,  41, 114,  59,  86,  85, 540,
#         89,  80,  78,  76,  60,  55,  54, 176,  47,  31,  40, 354,  48,
#        495])

# %%
checkouts_df["materialtype"] == "EBOOK"
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998    False
# 9999    False
# Name: materialtype, Length: 10000, dtype: bool

# %%
checkouts_df["checkouts"].max()
# Out:
# 540

# %%
# Zeige alle eBooks
checkouts_df[checkouts_df["materialtype"] == "EBOOK"]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0       Digital    OverDrive        EBOOK          2018              1
# 3       Digital    OverDrive        EBOOK          2018              1
# 4       Digital    OverDrive        EBOOK          2018              1
# 5       Digital    OverDrive        EBOOK          2018              1
# 6       Digital    OverDrive        EBOOK          2018              1
# ...         ...          ...          ...           ...            ...
# 9985    Digital    OverDrive        EBOOK          2018              1
# 9986    Digital    OverDrive        EBOOK          2018              1
# 9989    Digital    OverDrive        EBOOK          2018              1
# 9994    Digital    OverDrive        EBOOK          2018              1
# 9996    Digital    OverDrive        EBOOK          2018              1
#
#       checkouts                                              title  \
# ...

# %%
# Liste alle Materialtypen und das Erscheinungsjahr
checkouts_df[["materialtype","publicationyear"]]
# Out:
#      materialtype publicationyear
# 0           EBOOK            2017
# 1      TELEVISION             NaN
# 2       SOUNDDISC          [2015]
# 3           EBOOK            2009
# 4           EBOOK            2015
# ...           ...             ...
# 9995    AUDIOBOOK            2016
# 9996        EBOOK            2017
# 9997         BOOK           2014.
# 9998         BOOK          [2013]
# 9999    AUDIOBOOK            2012
#
# [10000 rows x 2 columns]

# %%
# Zeige alle eBooks, die 2014 oder später erschienen sind
checkouts_df[(checkouts_df["publicationyear"] >= "2014") & (checkouts_df["materialtype"] == "EBOOK")]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0       Digital    OverDrive        EBOOK          2018              1
# 4       Digital    OverDrive        EBOOK          2018              1
# 6       Digital    OverDrive        EBOOK          2018              1
# 11      Digital    OverDrive        EBOOK          2018              2
# 17      Digital    OverDrive        EBOOK          2018              2
# ...         ...          ...          ...           ...            ...
# 9981    Digital    OverDrive        EBOOK          2018              1
# 9984    Digital    OverDrive        EBOOK          2018              1
# 9985    Digital    OverDrive        EBOOK          2018              1
# 9994    Digital    OverDrive        EBOOK          2018              1
# 9996    Digital    OverDrive        EBOOK          2018              1
#
#       checkouts                                           title  \
# ...

# %%
# Zeige alle Medien, die 2014 oder später erschienen sind und die mind. 20 Mal ausgliehen wurden
checkouts_df[(checkouts_df["publicationyear"] >= "2014") & (checkouts_df["checkouts"] >= 20)]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0       Digital    OverDrive        EBOOK          2018              1
# 12      Digital    OverDrive    AUDIOBOOK          2018              2
# 138     Digital    OverDrive        EBOOK          2018              1
# 198    Physical      Horizon    VIDEODISC          2018              1
# 223     Digital    OverDrive    AUDIOBOOK          2018              1
# ...         ...          ...          ...           ...            ...
# 9651   Physical      Horizon         BOOK          2018              1
# 9659   Physical      Horizon    VIDEODISC          2018              1
# 9735   Physical      Horizon         BOOK          2018              1
# 9743   Physical      Horizon         BOOK          2018              1
# 9754   Physical      Horizon    VIDEODISC          2018              1
#
#       checkouts                                              title  \
# ...

# %%
# Zeige alle Materialtypen und Ausleihen, gruppiert nach Gesamtsummen pro Materialtyp
checkouts_df[["materialtype","checkouts"]].groupby("materialtype").sum()
# Out:
#                       checkouts
# materialtype
# ATLAS                         2
# AUDIOBOOK                  3115
# BOOK                      14180
# COMIC                       181
# CR                           10
# EBOOK                      5783
# ER                            4
# ER, SOUNDDISC                 4
# ER, VIDEODISC                 4
# LARGEPRINT                    3
# MAGAZINE                    727
# MAP                          11
# MOVIE                       232
# MUSIC                       200
# REGPRINT                     12
# SONG                        795
# SOUNDCASS                     1
# SOUNDDISC                  2048
# SOUNDDISC, VIDEODISC         23
# SOUNDREC                     48
# TELEVISION                  133
# VIDEO                         6
# VIDEOCASS, VIDEODISC          2
# VIDEODISC                  5866

# %%
# Zeige alle Ausleihen, beginne mit der höchsten Zahl
# Welches Medium wurde am häufigsten ausgeliehen?
checkouts_df.sort_values("checkouts",ascending=False)
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 6577   Physical      Horizon         BOOK          2018              1
# 9651   Physical      Horizon         BOOK          2018              1
# 9207    Digital        Zinio     MAGAZINE          2018              1
# 7732   Physical      Horizon    VIDEODISC          2018              1
# 6021   Physical      Horizon         BOOK          2018              1
# ...         ...          ...          ...           ...            ...
# 4376   Physical      Horizon         BOOK          2018              1
# 4374    Digital      Freegal         SONG          2018              1
# 4371   Physical      Horizon    SOUNDDISC          2018              1
# 4370   Physical      Horizon         BOOK          2018              1
# 9999    Digital    OverDrive    AUDIOBOOK          2018              1
#
#       checkouts                                              title  \
# ...
